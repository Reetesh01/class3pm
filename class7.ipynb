# %%
#string
a = 'hello world'
print(a)
print(type(a))
# Out:
# hello world
# <class 'str'>

# %%
a = 'hello'
b = 'world'
c= a+b
print(c)
# Out:
# helloworld

# %%
a = 'hello world\n'
print(a*5)
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world

# %%
a = 'Hello World'
print(a[4])
# Out:
# o

# %%
a = 'Hello World'
print(a[0:5])
# Out:
# Hello

# %%
a = 'Hello World'
print(a[0:10:1])
# Out:
# Hello Worl

# %%
a = 'Hello World'
print(a[0:10:2])
# Out:
# HloWr

# %%
a = 'Hello World'
print(a[0:10:4])
# Out:
# Hor

# %%
a = 'Hello World'
b = a[0:5]
c= a[5:]
print(b)
print(c)
# Out:
# Hello
#  World

# %%
a = 'hello world'
l = len(a)
print(a[l::-1])
# Out:
# dlrow olleh

# %%
#to print from back 
a = 'hello world'
print(a[-1],a[2],a[-3])
# Out:
# d l r

# %%
#string formatting

# %%
name =input("enter name = ")
age = int(input('enter age = '))
add = input("enter address = ")

info = "Hello i am "+ name +". I am from " +add+', i am '+str(age)+'years old.'

print(info)
# Out:
# enter name = sandesh
# enter age = 15
# enter address = ktm
# Hello i am sandesh. I am from ktm, i am 15years old.

# %%
s = str()
n = int(input('enter n = '))
for i in range(n):
    name = input("enter name = ")
    phone = int(input("enter phone number = "))
    info = f"{name} {phone}\n"
    s = s+info
    
print(s)
# Out:
# enter n = 2
# enter name = sandesh
# enter phone number = 986100000000
# enter name = ram
# enter phone number = 9860000000
# sandesh 986100000000
# ram 9860000000

# %%
a = "Ram Shyam Hari Sita Gita Nabin"
name = input("enter name = ")
if name in a:
    print('YESSSSSSSSSSSSSSSSSSSSSSSS')
    print(a.count(a))
# Out:
# enter name =Ram
# YESSSSSSSSSSSSSSSSSSSSSSSS
# 1

# %%
a = "Ram Shyam Hari Sita Gita Nabin"
a.upper()
# Out:
# 'RAM SHYAM HARI SITA GITA NABIN'

# %%
a = "Ram Shyam Hari Sita Gita Nabin"
a.lower()
# Out:
# 'ram shyam hari sita gita nabin'

# %%
a = "Ram Shyam Hari Sita Gita Nabin".lower()
name = input("enter name = ").lower()
if name in a:
    print('YESSSSSSSSSSSSSSSSSSSSSSSS!!!!!')
    print(a.count(name))
# Out:
# enter name = a
# YESSSSSSSSSSSSSSSSSSSSSSSS!!!!!
# 6

# %%
a = "Ram Shyam Hari Sita Gita Nabin"
a.title()
# Out:
# 'Ram Shyam Hari Sita Gita Nabin'

# %%
a = "Ram Shyam Hari Sita Gita Nabin"
a = a.upper()
print(a)
# Out:
# RAM SHYAM HARI SITA GITA NABIN

# %%
a = "Ram Shyam Hari Sita Gita Nabin"
a = a.replace('Ram','Sandesh')
print(a)
# Out:
# Sandesh Shyam Hari Sita Gita Nabin
