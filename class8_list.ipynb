# %%
# # python collections
# list
# tuple
# dictionary
# set

# %%
# list
# -indexed
# -ordered
# -multiple and duplicate data
# -mutable

# %%
#list
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
l = len(a)
print(l)
print(a)
print(type(a))
# Out:
# 5
# ['Apple', 'Ball', 'Cat', 'Dog', 'Fish']
# <class 'list'>

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
print(a[2])
# Out:
# Cat

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
print(a[1])
print(a[0:3])
print(a[0:4:2])
# Out:
# Ball
# ['Apple', 'Ball', 'Cat']
# ['Apple', 'Cat']

# %%
# oredered
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
b = [1,2,3,4,5]
c = a + b 
print(c)
# Out:
# ['Apple', 'Ball', 'Cat', 'Dog', 'Fish', 1, 2, 3, 4, 5]

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
b = [1,2,3,4,5]
c = b + a 
print(c)
# Out:
# [1, 2, 3, 4, 5, 'Apple', 'Ball', 'Cat', 'Dog', 'Fish']

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
print(a*2)
# Out:
# ['Apple', 'Ball', 'Cat', 'Dog', 'Fish', 'Apple', 'Ball', 'Cat', 'Dog', 'Fish']

# %%
#multiple and dupticate data
a = [1, 2, 3, 4, 5, 'Apple', 'Ball', 'Cat', 'Dog', 'Fish', 1, 2]
l = len(a)
l
# Out:
# 12

# %%
a = ['Apple', 'Ball', 'Cat', 'Dog', 'Fish']
a[0] = "Sandesh"
a
# Out:
# ['Sandesh', 'Ball', 'Cat', 'Dog', 'Fish']

# %%
l =[] # l = list()
n = int(input("enter n = "))
for i in range(n):
    x = int(input("enter x = "))
    l.append(x)
    
print(l)
# Out:
# enter n = 5
# enter x = 25
# enter x = 15
# enter x = 188
# enter x = 65
# enter x = 25
# [25, 15, 188, 65, 25]

# %%
# can be used in max sum min

# %%
a = [25, 15, 188, 65, 25]
print(max(a))
print(min(a))
print(sum(a))
# Out:
# 188
# 15
# 318

# %%
# sort() function
a = ["Apple", "zebra", "fish", "Ball", "golf"]
a.sort()
print(a)
# Out:
# ['Apple', 'Ball', 'fish', 'golf', 'zebra']

# %%
a = ["Apple", "zebra", "fish", "Ball", "golf"]
for i in(a):
    print(i)
# Out:
# Apple
# zebra
# fish
# Ball
# golf

# %%
a = ["Apple", "zebra", "fish", "Ball", "golf"]
if "Apple" in a:
    print("yes")
    print(a.count("Apple"))
# Out:
# yes
# 1

# %%
# append()
# insert()
# extend()

# %%
#append()
a= []
a.append('apple')
print(a)
# Out:
# ['apple']

# %%
#insert()
a = ["Apple", "zebra", "fish", "Ball", "golf"]
a.insert(1 , "Hello")
print(a)
# Out:
# ['Apple', 'Hello', 'zebra', 'fish', 'Ball', 'golf']

# %%
#extend()
a = ["Apple", "zebra", "fish", "Ball", "golf"]
b = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
a.extend(b)
print(a)
# Out:
# ['Apple', 'zebra', 'fish', 'Ball', 'golf', 'Apple', 'Ball', 'Cat', 'Dog', 'Fish']

# %%
#remove()
# del 
# pop()

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
a.remove("Apple")
a
# Out:
# ['Ball', 'Cat', 'Dog', 'Fish']

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
del a[0]
a
# Out:
# ['Ball', 'Cat', 'Dog', 'Fish']

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
del a[0:3]
a
# Out:
# ['Dog', 'Fish']

# %%
#index

a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
a.index("Apple")
# Out:
# 0

# %%
a = ["Apple", "Ball", "Cat" ,"Dog","Fish"]
a.index("Dog")
# Out:
# 3

# %%
a = ["Apple","Apple", "Ball", "Cat" , "Dog", "apple", "Ball", "Fish"]
l = a.count("Apple")
for i in range(l):
    if a[i] == "Apple":
        a.remove(a[i])
a
# Out:
# ['Apple', 'Ball', 'Cat', 'Dog', 'apple', 'Ball', 'Fish']

# %%
b = []
a = ["Apple","Apple", "Ball", "Cat" , "Dog", "Apple", "Ball", "Fish"]
for i in a:
    if i != "Apple":
        b.append(i)
print(b)
# Out:
# ['Ball', 'Cat', 'Dog', 'Ball', 'Fish']

# %%
#list inside list
#nested list

a = [[1,2,3],
    [4,5,6],
    [7,8,9]]
print(len(a))
# Out:
# 3

# %%
print(a[2])
# Out:
# [7, 8, 9]

# %%
a= [['sandesh',65,'Lubhu'],
   ['Ram', 82, 'Patan'],
   ['Hari',24, 'Ktm']]
a
# Out:
# [['sandesh', 65, 'Lubhu'], ['Ram', 82, 'Patan'], ['Hari', 24, 'Ktm']]

# %%
a[0][2]
# Out:
# 'Lubhu'

# %%
a[0]
# Out:
# ['sandesh', 65, 'Lubhu']

# %%
name = input('enter name =')
for i in a:
    if name in i:
        print(i)
# Out:
# enter name =Hari
# ['Hari', 24, 'Ktm']

# %%
info = []
n = int(input("enter n = "))
for i in range(n):
    name = input('enter name = ')
    age =  int(input("age = "))
    ads = input("enter address = ")
    
    data = [name,age,ads]
    info.append(data)
print(info)
# Out:
# enter n = 2
# enter name = san
# age = 12
# enter address = kt,
# enter name = gol
# age = 2
# enter address = ktm
# [['san', 12, 'kt,'], ['gol', 2, 'ktm']]

# %%
a = [['sandesh', 65, 'Lubhu'], ['Ram', 82, 'Patan'], ['Hari', 24, 'Ktm']]
a[0][0] = 'Ram parsad'
a
# Out:
# [['Ram parsad', 65, 'Lubhu'], ['Ram', 82, 'Patan'], ['Hari', 24, 'Ktm']]

# %%
a = [['sandesh', 65, 'Lubhu'], ['Ram', 82, 'Patan'], ['Hari', 24, 'Ktm']]
a.append(['Ram',52,'BKT'])
a
# Out:
# [['sandesh', 65, 'Lubhu'],
#  ['Ram', 82, 'Patan'],
#  ['Hari', 24, 'Ktm'],
#  ['Ram', 52, 'BKT']]

# %%
a = [['sandesh', 65, 'Lubhu'], ['Ram', 82, 'Patan'], ['Hari', 24, 'Ktm']]

name = input('enter name =')
for i in a:
    if name in i :
        a.remove(i)
a
# Out:
# enter name =sandesh
# [['Ram', 82, 'Patan'], ['Hari', 24, 'Ktm']]
