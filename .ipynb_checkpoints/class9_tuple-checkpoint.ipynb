# %%
#tuple
# -indexed
# -ordered
# -multiple and duplicate data
# -imutable

# %%
a = tuple()
a = (1,2,3,4,5,6,7,8,9,)
print(a)
print(type(a))
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)
# <class 'tuple'>

# %%
a = (1)
b = ("Apple")
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = (1,)
b = ("Apple",)
print(type(a))
print(type(b))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
# indexed
a =("Apple","Ball","Cat","Dog","Fish",)
print(a[0])
print(a[0:4])
print(a[0:4:2])
# Out:
# Apple
# ('Apple', 'Ball', 'Cat', 'Dog')
# ('Apple', 'Cat')

# %%
a =("Apple","Ball","Cat","Dog",)
b = ("Fish",)
c = a+b
print(c)
# Out:
# ('Apple', 'Ball', 'Cat', 'Dog', 'Fish')

# %%
a =("Apple","Ball","Cat","Dog",)
c = a*2
print(c)
# Out:
# ('Apple', 'Ball', 'Cat', 'Dog', 'Apple', 'Ball', 'Cat', 'Dog')

# %%
no append(), no insert(), no extend()
no update
no del remove() pop()
# Out:
#   Input In [13]
#     no append(), no insert(), no extend()
#        ^
# SyntaxError: invalid syntax

# %%
# no append(), no insert(), no extend()
# no update
# no del, no remove(), no pop()

# %%
t = tuple()
n = int(input("enter n = "))
for i in range(n):
    x = input('Enter x = ')
    t = t + (x,)
    
print(t)
# Out:
# enter n = 3
# Enter x = ram
# Enter x = shyam
# Enter x = hari
# ('ram', 'shyam', 'hari')

# %%
def cal():
    a = 12
    v = 10
    return a,v

cal()
# Out:
# (12, 10)

# %%
a= 10,120,45
a
# Out:
# (10, 120, 45)

# %%
a = ('Apple', 'Ball', 'Cat', 'Dog', 'Fish')
b = list(a)
b
# Out:
# ['Apple', 'Ball', 'Cat', 'Dog', 'Fish']

# %%
a = ('Apple', 'Ball', 'Cat', 'Dog', 'Fish')
b = list(a)
del b[0]
a = tuple(b)
a
# Out:
# ('Ball', 'Cat', 'Dog', 'Fish')

# %%
# tuple inside tuple
# nested tuple

# %%
a = (('sandesh', 65, 'Lubhu'),
     ('Ram', 82, 'Patan'),
    ('Hari', 24, 'Ktm'),
     ('Ram', 52, 'BKT'))
a
# Out:
# (('sandesh', 65, 'Lubhu'),
#  ('Ram', 82, 'Patan'),
#  ('Hari', 24, 'Ktm'),
#  ('Ram', 52, 'BKT'))

# %%
a = (('sandesh', 65, 'Lubhu'),
     ('Ram', 82, 'Patan'),
    ('Hari', 24, 'Ktm'),
     ('Ram', 52, 'BKT'))
b = (('Nabin', 25, 'chitwan'),)
print(a+b)
# Out:
# (('sandesh', 65, 'Lubhu'), ('Ram', 82, 'Patan'), ('Hari', 24, 'Ktm'), ('Ram', 52, 'BKT'), ('Nabin', 25, 'chitwan'))

# %%
#wap to determine tuple inside tuple

# %%
a = (('sandesh', 65, 'Lubhu'), ('Ram', 82, 'Patan'), ('Hari', 24, 'Ktm'), ('Ram', 52, 'BKT'), ('Nabin', 25, 'chitwan'))
b = list(a)
b
# Out:
# [('sandesh', 65, 'Lubhu'),
#  ('Ram', 82, 'Patan'),
#  ('Hari', 24, 'Ktm'),
#  ('Ram', 52, 'BKT'),
#  ('Nabin', 25, 'chitwan')]

# %%
del b[0]
b
# Out:
# [('Ram', 82, 'Patan'),
#  ('Hari', 24, 'Ktm'),
#  ('Ram', 52, 'BKT'),
#  ('Nabin', 25, 'chitwan')]

# %%
b.append(('nisant', 45,'Ktm'),)
b
# Out:
# [('Ram', 82, 'Patan'),
#  ('Hari', 24, 'Ktm'),
#  ('Ram', 52, 'BKT'),
#  ('Nabin', 25, 'chitwan'),
#  ('nisant', 45, 'Ktm')]

# %%
#wap to convet tuple to list inside list ###([])
#wap to perform CRUD list inside tuple
