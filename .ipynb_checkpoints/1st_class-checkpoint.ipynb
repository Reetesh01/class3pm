# %%
print('hello world')
# Out:
# hello world

# %%
a = 10 
b = 30 
a+b
# Out:
# 40

# %%
a = float(input('enter a variable : '))
b = float(input('enter second vriable : '))
c = a+b
print('the sum is', float(c))
# Out:
# enter a variable : 15.5
# enter second vriable : 152.3
# the sum is 167.8

# %%
a = 10
b = 52.1
c = "ritesh"
d = True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
<class'int'>
<class'float'>
<class'bool'>
<class'str'>
# Out:
#   File "C:\Users\ReeTeeSH\AppData\Local\Temp/ipykernel_8104/4207272654.py", line 1
#     <class'int'>
#     ^
# SyntaxError: invalid syntax

# %%
a=10 
b=3
c=a%b
print(c)
# Out:
# 1

# %%
a=10 
b=3
c=a//b
print(c)
# Out:
# 3

# %%
a=10 
b=3
c=a**b
print(c)
# Out:
# 1000

# %%
a=10 
b=3
c=a-b
print(c)
# Out:
# 7

# %%
a=10 
b=3
c=a+b
print(c)
# Out:
# 13

# %%
r=3
a=3.14*r**2
print(a)
# Out:
# 28.26

# %%
a = int(input('enter a variable : '))
b = int(input('enter second vriable : '))
c = a+b
print('the sum is', int(c))
# Out:
# enter a variable : 15
# enter second vriable : 15
# the sum is 30

# %%
p = int(input('enter a principle : '))
t = float(input('enter time : '))
r = float(input('enter rate: '))

i = p*r*t/100
          
print('The value of i = ', float(i))
# Out:
# enter a principle : 1000
# enter time : 2.5
# enter rate: 10
# The value of i =  250.0

# %%
a = "hello world\n"
print(a*5)
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world

# %%
a = 1+2j
print(type(a))
# Out:
# <class 'complex'>
